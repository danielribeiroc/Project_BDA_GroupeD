# %%
import numpy as np
import os
import json

# %%
# Iterates through all the files and subfolders in open-data/data/matches folder and store the data in an array
matches = []

for root, dirs, files in os.walk("open-data/data/matches"):
    for file in files:
        if file.endswith(".json"):
            with open(os.path.join(root, file), 'r') as f:
                content = json.load(f)
                for match in content:
                    matches.append(match)
# Out:
# 2886

# %%
# Number of matches in the dataset
len(matches)
# Out:
# 2886

# %%
# Number of unique matches in the dataset
len(set([match['match_id'] for match in matches]))
# Out:
# 2886

# %%
# Number of unique competitions in the dataset
len(set([match['competition']['competition_id'] for match in matches]))
# Out:
# 19

# %%
# Number of unique seasons in the dataset
len(set([match['season']['season_id'] for match in matches]))
# Out:
# 44

# %%
# Number of unique teams in the dataset
teams = set()
for match in matches:
    teams.add(match['home_team']['home_team_id'])
    teams.add(match['away_team']['away_team_id'])
len(teams)
# Out:
# 276

# %%
# Count of each scoreline in the dataset
scorelines = {}
for match in matches:
    scoreline = str(match['home_score']) + '-' + str(match['away_score'])
    if scoreline in scorelines:
        scorelines[scoreline] += 1
    else:
        scorelines[scoreline] = 1

# Sort the scorelines by count
sorted_scorelines = {k: v for k, v in sorted(scorelines.items(), key=lambda item: item[1], reverse=True)}
sorted_scorelines
# Out:
# {'1-1': 285,
#  '1-0': 259,
#  '2-1': 244,
#  '2-0': 216,
#  '0-1': 208,
#  '1-2': 180,
#  '0-0': 180,
#  '0-2': 141,
#  '2-2': 132,
#  '3-1': 127,
#  '3-0': 119,
#  '1-3': 90,
#  '0-3': 83,
#  '4-0': 65,
#  '3-2': 61,
#  '4-1': 54,
#  '0-4': 53,
#  '2-3': 50,
#  '5-0': 39,
#  '5-1': 34,
#  '1-4': 33,
#  '3-3': 33,
#  '4-2': 26,
#  '0-5': 24,
#  '2-4': 20,
#  '6-0': 17,
#  '6-1': 16,
#  '1-5': 14,
#  '5-2': 13,
#  '0-6': 8,
#  '3-4': 7,
#  '4-3': 7,
#  '6-2': 6,
#  '1-6': 4,
#  '7-0': 4,
#  '0-8': 3,
#  '2-5': 3,
#  '7-1': 3,
#  '8-0': 3,
#  '0-7': 3,
#  '4-4': 2,
#  '3-5': 2,
#  '4-5': 2,
#  '1-7': 2,
#  '6-4': 1,
#  '2-6': 1,
#  '10-2': 1,
#  '8-2': 1,
#  '5-3': 1,
#  '13-0': 1,
#  '3-6': 1,
#  '9-0': 1,
#  '8-1': 1,
#  '1-9': 1,
#  '11-1': 1}

# %%
# Number of draws, home wins and away wins in the dataset
draws = 0
home_wins = 0
away_wins = 0

for match in matches:
    if match['home_score'] == match['away_score']:
        draws += 1
    elif match['home_score'] > match['away_score']:
        home_wins += 1
    else:
        away_wins += 1

draws, home_wins, away_wins
# Out:
# (632, 1321, 933)

# %%
# Number of matches in each competition
competition_matches = {}

for match in matches:
    competition_id = match['competition']['competition_id']
    if competition_id in competition_matches:
        competition_matches[competition_id] += 1
    else:
        competition_matches[competition_id] = 1

# Sort the competitions by number of matches
sorted_competition_matches = {k: v for k, v in sorted(competition_matches.items(), key=lambda item: item[1], reverse=True)}

# Replace ids with names, they are stored in match['competition']['competition_name']
competition_names = {}
for match in matches:
    competition_id = match['competition']['competition_id']
    competition_name = match['competition']['competition_name']
    competition_names[competition_id] = competition_name
    
sorted_competition_matches = {competition_names[k]: v for k, v in sorted_competition_matches.items()}
sorted_competition_matches
# Out:
# {'La Liga': 868,
#  'Premier League': 418,
#  'Serie A': 381,
#  "FA Women's Super League": 326,
#  '1. Bundesliga': 306,
#  'FIFA World Cup': 147,
#  "Women's World Cup": 116,
#  'Indian Super league': 115,
#  'Ligue 1': 58,
#  'UEFA Euro': 51,
#  'NWSL': 36,
#  "UEFA Women's Euro": 31,
#  'Champions League': 17,
#  'Major League Soccer': 6,
#  'UEFA Europa League': 3,
#  'Copa del Rey': 3,
#  'Liga Profesional': 2,
#  'North American League': 1,
#  'FIFA U20 World Cup': 1}

# %%
# Statistics for each team
team_stats = {}

for match in matches:
    home_team_id = match['home_team']['home_team_id']
    away_team_id = match['away_team']['away_team_id']
    
    if home_team_id not in team_stats:
        team_stats[home_team_id] = {'team_name': match['home_team']['home_team_name'], 'matches': 0, 'wins': 0, 'draws': 0, 'losses': 0, 'goals_scored': 0, 'goals_conceded': 0}
    if away_team_id not in team_stats:
        team_stats[away_team_id] = {'team_name': match['away_team']['away_team_name'], 'matches': 0, 'wins': 0, 'draws': 0, 'losses': 0, 'goals_scored': 0, 'goals_conceded': 0}
    
    team_stats[home_team_id]['matches'] += 1
    team_stats[away_team_id]['matches'] += 1
    
    team_stats[home_team_id]['goals_scored'] += match['home_score']
    team_stats[home_team_id]['goals_conceded'] += match['away_score']
    team_stats[away_team_id]['goals_scored'] += match['away_score']
    team_stats[away_team_id]['goals_conceded'] += match['home_score']
    
    if match['home_score'] == match['away_score']:
        team_stats[home_team_id]['draws'] += 1
        team_stats[away_team_id]['draws'] += 1
    elif match['home_score'] > match['away_score']:
        team_stats[home_team_id]['wins'] += 1
        team_stats[away_team_id]['losses'] += 1
    else:
        team_stats[home_team_id]['losses'] += 1
        team_stats[away_team_id]['wins'] += 1

# Sort the teams by number of matches
sorted_team_stats = {k: v for k, v in sorted(team_stats.items(), key=lambda item: item[1]['matches'], reverse=True)}
sorted_team_stats
# Out:
# {217: {'team_name': 'Barcelona',
#   'matches': 532,
#   'wins': 393,
#   'draws': 86,
#   'losses': 53,
#   'goals_scored': 1409,
#   'goals_conceded': 444},
#  1: {'team_name': 'Arsenal',
#   'matches': 76,
#   'wins': 46,
#   'draws': 23,
#   'losses': 7,
#   'goals_scored': 138,
#   'goals_conceded': 62},
#  220: {'team_name': 'Real Madrid',
#   'matches': 71,
#   'wins': 39,
#   'draws': 13,
#   'losses': 19,
#   'goals_scored': 162,
#   'goals_conceded': 97},
#  212: {'team_name': 'Atlético Madrid',
#   'matches': 68,
#   'wins': 33,
#   'draws': 12,
#   'losses': 23,
#   'goals_scored': 94,
#   'goals_conceded': 84},
#  213: {'team_name': 'Sevilla',
#   'matches': 66,
#   'wins': 15,
#   'draws': 17,
#   'losses': 34,
#   'goals_scored': 78,
#   'goals_conceded': 120},
#  207: {'team_name': 'Valencia',
#   'matches': 65,
#   'wins': 14,
#   'draws': 20,
#   'losses': 31,
#   'goals_scored': 76,
#   'goals_conceded': 106},
#  215: {'team_name': 'Athletic Club',
#   'matches': 64,
#   'wins': 19,
#   'draws': 14,
#   'losses': 31,
#   'goals_scored': 78,
#   'goals_conceded': 101},
#  214: {'team_name': 'Espanyol',
#   'matches': 63,
#   'wins': 13,
#   'draws': 14,
#   'losses': 36,
#   'goals_scored': 54,
#   'goals_conceded': 130},
#  222: {'team_name': 'Villarreal',
#   'matches': 61,
#   'wins': 20,
#   'draws': 14,
#   'losses': 27,
#   'goals_scored': 69,
#   'goals_conceded': 93},
#  216: {'team_name': 'Getafe',
#   'matches': 61,
#   'wins': 12,
#   'draws': 12,
#   'losses': 37,
#   'goals_scored': 54,
#   'goals_conceded': 118},
#  210: {'team_name': 'Real Sociedad',
#   'matches': 59,
#   'wins': 17,
#   'draws': 12,
#   'losses': 30,
#   'goals_scored': 70,
#   'goals_conceded': 98},
#  746: {'team_name': 'Manchester City WFC',
#   'matches': 59,
#   'wins': 44,
#   'draws': 11,
#   'losses': 4,
#   'goals_scored': 159,
#   'goals_conceded': 41},
#  218: {'team_name': 'Real Betis',
#   'matches': 58,
#   'wins': 12,
#   'draws': 16,
#   'losses': 30,
#   'goals_scored': 63,
#   'goals_conceded': 117},
#  131: {'team_name': 'Paris Saint-Germain',
#   'matches': 58,
#   'wins': 40,
#   'draws': 10,
#   'losses': 8,
#   'goals_scored': 141,
#   'goals_conceded': 54},
#  221: {'team_name': 'Levante UD',
#   'matches': 57,
#   'wins': 9,
#   'draws': 11,
#   'losses': 37,
#   'goals_scored': 50,
#   'goals_conceded': 128},
#  968: {'team_name': 'Arsenal WFC',
#   'matches': 57,
#   'wins': 45,
#   'draws': 3,
#   'losses': 9,
#   'goals_scored': 173,
#   'goals_conceded': 41},
#  965: {'team_name': 'Brighton & Hove Albion WFC',
#   'matches': 57,
#   'wins': 15,
#   'draws': 11,
#   'losses': 31,
#   'goals_scored': 48,
#   'goals_conceded': 108},
#  971: {'team_name': 'Chelsea FCW',
#   'matches': 57,
#   'wins': 41,
#   'draws': 13,
#   'losses': 3,
#   'goals_scored': 156,
#   'goals_conceded': 37},
#  972: {'team_name': 'West Ham United LFC',
#   'matches': 56,
#   'wins': 15,
#   'draws': 9,
#   'losses': 32,
#   'goals_scored': 65,
#   'goals_conceded': 110},
#  974: {'team_name': 'Reading WFC',
#   'matches': 56,
#   'wins': 19,
#   'draws': 15,
#   'losses': 22,
#   'goals_scored': 79,
#   'goals_conceded': 95},
#  973: {'team_name': 'Bristol City WFC',
#   'matches': 56,
#   'wins': 11,
#   'draws': 13,
#   'losses': 32,
#   'goals_scored': 44,
#   'goals_conceded': 144},
#  967: {'team_name': 'Everton LFC',
#   'matches': 55,
#   'wins': 18,
#   'draws': 9,
#   'losses': 28,
#   'goals_scored': 74,
#   'goals_conceded': 86},
#  209: {'team_name': 'Celta Vigo',
#   'matches': 54,
#   'wins': 19,
#   'draws': 13,
#   'losses': 22,
#   'goals_scored': 66,
#   'goals_conceded': 97},
#  223: {'team_name': 'Málaga',
#   'matches': 53,
#   'wins': 14,
#   'draws': 13,
#   'losses': 26,
#   'goals_scored': 47,
#   'goals_conceded': 75},
#  219: {'team_name': 'RC Deportivo La Coruña',
#   'matches': 53,
#   'wins': 9,
#   'draws': 20,
#   'losses': 24,
#   'goals_scored': 59,
#   'goals_conceded': 107},
#  969: {'team_name': 'Birmingham City WFC',
#   'matches': 53,
#   'wins': 17,
#   'draws': 8,
#   'losses': 28,
#   'goals_scored': 48,
#   'goals_conceded': 84},
#  1049: {'team_name': 'Granada',
#   'matches': 50,
#   'wins': 13,
#   'draws': 9,
#   'losses': 28,
#   'goals_scored': 56,
#   'goals_conceded': 95},
#  322: {'team_name': 'Eibar',
#   'matches': 48,
#   'wins': 11,
#   'draws': 11,
#   'losses': 26,
#   'goals_scored': 54,
#   'goals_conceded': 95},
#  360: {'team_name': 'Rayo Vallecano',
#   'matches': 47,
#   'wins': 9,
#   'draws': 11,
#   'losses': 27,
#   'goals_scored': 55,
#   'goals_conceded': 113},
#  1041: {'team_name': 'Sporting Gijón',
#   'matches': 44,
#   'wins': 10,
#   'draws': 10,
#   'losses': 24,
#   'goals_scored': 44,
#   'goals_conceded': 80},
#  24: {'team_name': 'Liverpool',
#   'matches': 44,
#   'wins': 17,
#   'draws': 13,
#   'losses': 14,
#   'goals_scored': 73,
#   'goals_conceded': 64},
#  208: {'team_name': 'Las Palmas',
#   'matches': 43,
#   'wins': 12,
#   'draws': 9,
#   'losses': 22,
#   'goals_scored': 48,
#   'goals_conceded': 69},
#  227: {'team_name': 'Napoli',
#   'matches': 42,
#   'wins': 29,
#   'draws': 7,
#   'losses': 6,
#   'goals_scored': 90,
#   'goals_conceded': 34},
#  39: {'team_name': 'Manchester United',
#   'matches': 42,
#   'wins': 19,
#   'draws': 11,
#   'losses': 12,
#   'goals_scored': 51,
#   'goals_conceded': 41},
#  224: {'team_name': 'Juventus',
#   'matches': 42,
#   'wins': 29,
#   'draws': 4,
#   'losses': 9,
#   'goals_scored': 78,
#   'goals_conceded': 31},
#  38: {'team_name': 'Tottenham Hotspur',
#   'matches': 41,
#   'wins': 19,
#   'draws': 14,
#   'losses': 8,
#   'goals_scored': 72,
#   'goals_conceded': 41},
#  33: {'team_name': 'Chelsea',
#   'matches': 41,
#   'wins': 12,
#   'draws': 15,
#   'losses': 14,
#   'goals_scored': 62,
#   'goals_conceded': 58},
#  243: {'team_name': 'AC Milan',
#   'matches': 40,
#   'wins': 16,
#   'draws': 13,
#   'losses': 11,
#   'goals_scored': 54,
#   'goals_conceded': 47},
#  238: {'team_name': 'Inter Milan',
#   'matches': 40,
#   'wins': 21,
#   'draws': 7,
#   'losses': 12,
#   'goals_scored': 52,
#   'goals_conceded': 40},
#  22: {'team_name': 'Leicester City',
#   'matches': 40,
#   'wins': 23,
#   'draws': 13,
#   'losses': 4,
#   'goals_scored': 70,
#   'goals_conceded': 39},
#  37: {'team_name': 'Newcastle United',
#   'matches': 40,
#   'wins': 9,
#   'draws': 11,
#   'losses': 20,
#   'goals_scored': 46,
#   'goals_conceded': 68},
#  59: {'team_name': 'Aston Villa',
#   'matches': 40,
#   'wins': 3,
#   'draws': 8,
#   'losses': 29,
#   'goals_scored': 27,
#   'goals_conceded': 80},
#  29: {'team_name': 'Everton',
#   'matches': 40,
#   'wins': 11,
#   'draws': 15,
#   'losses': 14,
#   'goals_scored': 61,
#   'goals_conceded': 58},
#  36: {'team_name': 'Manchester City',
#   'matches': 40,
#   'wins': 19,
#   'draws': 9,
#   'losses': 12,
#   'goals_scored': 73,
#   'goals_conceded': 45},
#  25: {'team_name': 'Southampton',
#   'matches': 40,
#   'wins': 18,
#   'draws': 9,
#   'losses': 13,
#   'goals_scored': 59,
#   'goals_conceded': 44},
#  169: {'team_name': 'Bayern Munich',
#   'matches': 38,
#   'wins': 29,
#   'draws': 5,
#   'losses': 4,
#   'goals_scored': 83,
#   'goals_conceded': 23},
#  228: {'team_name': 'Atalanta',
#   'matches': 38,
#   'wins': 11,
#   'draws': 12,
#   'losses': 15,
#   'goals_scored': 41,
#   'goals_conceded': 47},
#  230: {'team_name': 'Udinese',
#   'matches': 38,
#   'wins': 10,
#   'draws': 9,
#   'losses': 19,
#   'goals_scored': 35,
#   'goals_conceded': 60},
#  291: {'team_name': 'Frosinone',
#   'matches': 38,
#   'wins': 8,
#   'draws': 7,
#   'losses': 23,
#   'goals_scored': 35,
#   'goals_conceded': 76},
#  241: {'team_name': 'Torino',
#   'matches': 38,
#   'wins': 12,
#   'draws': 9,
#   'losses': 17,
#   'goals_scored': 52,
#   'goals_conceded': 55},
#  236: {'team_name': 'Lazio',
#   'matches': 38,
#   'wins': 15,
#   'draws': 9,
#   'losses': 14,
#   'goals_scored': 52,
#   'goals_conceded': 52},
#  290: {'team_name': 'Empoli',
#   'matches': 38,
#   'wins': 12,
#   'draws': 10,
#   'losses': 16,
#   'goals_scored': 40,
#   'goals_conceded': 49},
#  239: {'team_name': 'Fiorentina',
#   'matches': 38,
#   'wins': 18,
#   'draws': 10,
#   'losses': 10,
#   'goals_scored': 60,
#   'goals_conceded': 42},
#  229: {'team_name': 'AS Roma',
#   'matches': 38,
#   'wins': 23,
#   'draws': 11,
#   'losses': 4,
#   'goals_scored': 83,
#   'goals_conceded': 41},
#  232: {'team_name': 'Sassuolo',
#   'matches': 38,
#   'wins': 16,
#   'draws': 13,
#   'losses': 9,
#   'goals_scored': 49,
#   'goals_conceded': 40},
#  240: {'team_name': 'Bologna',
#   'matches': 38,
#   'wins': 11,
#   'draws': 9,
#   'losses': 18,
#   'goals_scored': 33,
#   'goals_conceded': 45},
#  234: {'team_name': 'Sampdoria',
#   'matches': 38,
#   'wins': 10,
#   'draws': 10,
#   'losses': 18,
#   'goals_scored': 48,
#   'goals_conceded': 61},
#  231: {'team_name': 'Chievo',
#   'matches': 38,
#   'wins': 13,
#   'draws': 11,
#   'losses': 14,
#   'goals_scored': 43,
#   'goals_conceded': 45},
#  226: {'team_name': 'Hellas Verona',
#   'matches': 38,
#   'wins': 5,
#   'draws': 13,
#   'losses': 20,
#   'goals_scored': 34,
#   'goals_conceded': 63},
#  2256: {'team_name': 'Palermo',
#   'matches': 38,
#   'wins': 10,
#   'draws': 9,
#   'losses': 19,
#   'goals_scored': 38,
#   'goals_conceded': 65},
#  233: {'team_name': 'Genoa',
#   'matches': 38,
#   'wins': 13,
#   'draws': 7,
#   'losses': 18,
#   'goals_scored': 45,
#   'goals_conceded': 48},
#  1683: {'team_name': 'Carpi',
#   'matches': 38,
#   'wins': 9,
#   'draws': 11,
#   'losses': 18,
#   'goals_scored': 37,
#   'goals_conceded': 57},
#  28: {'team_name': 'AFC Bournemouth',
#   'matches': 38,
#   'wins': 11,
#   'draws': 9,
#   'losses': 18,
#   'goals_scored': 45,
#   'goals_conceded': 67},
#  27: {'team_name': 'West Bromwich Albion',
#   'matches': 38,
#   'wins': 10,
#   'draws': 13,
#   'losses': 15,
#   'goals_scored': 34,
#   'goals_conceded': 48},
#  41: {'team_name': 'Sunderland',
#   'matches': 38,
#   'wins': 9,
#   'draws': 12,
#   'losses': 17,
#   'goals_scored': 48,
#   'goals_conceded': 62},
#  31: {'team_name': 'Crystal Palace',
#   'matches': 38,
#   'wins': 11,
#   'draws': 9,
#   'losses': 18,
#   'goals_scored': 39,
#   'goals_conceded': 51},
#  23: {'team_name': 'Watford',
#   'matches': 38,
#   'wins': 12,
#   'draws': 9,
#   'losses': 17,
#   'goals_scored': 40,
#   'goals_conceded': 50},
#  56: {'team_name': 'Norwich City',
#   'matches': 38,
#   'wins': 9,
#   'draws': 7,
#   'losses': 22,
#   'goals_scored': 39,
#   'goals_conceded': 67},
#  30: {'team_name': 'Stoke City',
#   'matches': 38,
#   'wins': 14,
#   'draws': 9,
#   'losses': 15,
#   'goals_scored': 41,
#   'goals_conceded': 55},
#  40: {'team_name': 'West Ham United',
#   'matches': 38,
#   'wins': 16,
#   'draws': 14,
#   'losses': 8,
#   'goals_scored': 65,
#   'goals_conceded': 51},
#  26: {'team_name': 'Swansea City',
#   'matches': 38,
#   'wins': 12,
#   'draws': 11,
#   'losses': 15,
#   'goals_scored': 42,
#   'goals_conceded': 52},
#  749: {'team_name': 'Tottenham Hotspur Women',
#   'matches': 36,
#   'wins': 10,
#   'draws': 7,
#   'losses': 19,
#   'goals_scored': 33,
#   'goals_conceded': 65},
#  1475: {'team_name': 'Manchester United',
#   'matches': 36,
#   'wins': 22,
#   'draws': 4,
#   'losses': 10,
#   'goals_scored': 68,
#   'goals_conceded': 32},
#  174: {'team_name': 'VfB Stuttgart',
#   'matches': 35,
#   'wins': 9,
#   'draws': 6,
#   'losses': 20,
#   'goals_scored': 51,
#   'goals_conceded': 77},
#  180: {'team_name': 'Borussia Dortmund',
#   'matches': 35,
#   'wins': 24,
#   'draws': 6,
#   'losses': 5,
#   'goals_scored': 83,
#   'goals_conceded': 36},
#  175: {'team_name': 'Hoffenheim',
#   'matches': 34,
#   'wins': 9,
#   'draws': 10,
#   'losses': 15,
#   'goals_scored': 39,
#   'goals_conceded': 54},
#  181: {'team_name': 'Schalke 04',
#   'matches': 34,
#   'wins': 15,
#   'draws': 7,
#   'losses': 12,
#   'goals_scored': 51,
#   'goals_conceded': 49},
#  184: {'team_name': 'Eintracht Frankfurt',
#   'matches': 34,
#   'wins': 9,
#   'draws': 9,
#   'losses': 16,
#   'goals_scored': 34,
#   'goals_conceded': 52},
#  173: {'team_name': 'Hertha Berlin',
#   'matches': 34,
#   'wins': 14,
#   'draws': 8,
#   'losses': 12,
#   'goals_scored': 42,
#   'goals_conceded': 42},
#  178: {'team_name': 'Hannover 96',
#   'matches': 34,
#   'wins': 7,
#   'draws': 4,
#   'losses': 23,
#   'goals_scored': 31,
#   'goals_conceded': 62},
#  171: {'team_name': 'Hamburger SV',
#   'matches': 34,
#   'wins': 11,
#   'draws': 8,
#   'losses': 15,
#   'goals_scored': 40,
#   'goals_conceded': 46},
#  872: {'team_name': 'Darmstadt 98',
#   'matches': 34,
#   'wins': 9,
#   'draws': 11,
#   'losses': 14,
#   'goals_scored': 38,
#   'goals_conceded': 53},
#  177: {'team_name': 'FSV Mainz 05',
#   'matches': 34,
#   'wins': 14,
#   'draws': 8,
#   'losses': 12,
#   'goals_scored': 46,
#   'goals_conceded': 42},
#  179: {'team_name': 'Wolfsburg',
#   'matches': 34,
#   'wins': 12,
#   'draws': 9,
#   'losses': 13,
#   'goals_scored': 47,
#   'goals_conceded': 49},
#  172: {'team_name': 'Augsburg',
#   'matches': 34,
#   'wins': 9,
#   'draws': 11,
#   'losses': 14,
#   'goals_scored': 42,
#   'goals_conceded': 52},
#  176: {'team_name': 'Werder Bremen',
#   'matches': 34,
#   'wins': 10,
#   'draws': 8,
#   'losses': 16,
#   'goals_scored': 50,
#   'goals_conceded': 65},
#  904: {'team_name': 'Bayer Leverkusen',
#   'matches': 34,
#   'wins': 18,
#   'draws': 6,
#   'losses': 10,
#   'goals_scored': 56,
#   'goals_conceded': 40},
#  189: {'team_name': 'Ingolstadt',
#   'matches': 34,
#   'wins': 10,
#   'draws': 10,
#   'losses': 14,
#   'goals_scored': 33,
#   'goals_conceded': 42},
#  186: {'team_name': 'FC Köln',
#   'matches': 34,
#   'wins': 10,
#   'draws': 13,
#   'losses': 11,
#   'goals_scored': 38,
#   'goals_conceded': 42},
#  185: {'team_name': 'Borussia Mönchengladbach',
#   'matches': 34,
#   'wins': 17,
#   'draws': 4,
#   'losses': 13,
#   'goals_scored': 67,
#   'goals_conceded': 50},
#  966: {'team_name': 'Liverpool WFC',
#   'matches': 33,
#   'wins': 7,
#   'draws': 4,
#   'losses': 22,
#   'goals_scored': 26,
#   'goals_conceded': 57},
#  7289: {'team_name': 'Hyderabad',
#   'matches': 23,
#   'wins': 12,
#   'draws': 6,
#   'losses': 5,
#   'goals_scored': 47,
#   'goals_conceded': 26},
#  7283: {'team_name': 'Kerala Blasters',
#   'matches': 23,
#   'wins': 10,
#   'draws': 9,
#   'losses': 4,
#   'goals_scored': 37,
#   'goals_conceded': 26},
#  2021: {'team_name': 'Jamshedpur',
#   'matches': 22,
#   'wins': 13,
#   'draws': 5,
#   'losses': 4,
#   'goals_scored': 43,
#   'goals_conceded': 23},
#  7282: {'team_name': 'ATK Mohun Bagan',
#   'matches': 22,
#   'wins': 11,
#   'draws': 7,
#   'losses': 4,
#   'goals_scored': 39,
#   'goals_conceded': 29},
#  2647: {'team_name': 'Aston Villa',
#   'matches': 22,
#   'wins': 3,
#   'draws': 6,
#   'losses': 13,
#   'goals_scored': 15,
#   'goals_conceded': 47},
#  781: {'team_name': 'Brazil',
#   'matches': 21,
#   'wins': 15,
#   'draws': 2,
#   'losses': 4,
#   'goals_scored': 47,
#   'goals_conceded': 20},
#  768: {'team_name': 'England',
#   'matches': 21,
#   'wins': 11,
#   'draws': 4,
#   'losses': 6,
#   'goals_scored': 37,
#   'goals_conceded': 17},
#  7286: {'team_name': 'East Bengal',
#   'matches': 20,
#   'wins': 1,
#   'draws': 8,
#   'losses': 11,
#   'goals_scored': 18,
#   'goals_conceded': 36},
#  7284: {'team_name': 'Bengaluru',
#   'matches': 20,
#   'wins': 8,
#   'draws': 5,
#   'losses': 7,
#   'goals_scored': 32,
#   'goals_conceded': 27},
#  7288: {'team_name': 'Goa',
#   'matches': 20,
#   'wins': 4,
#   'draws': 7,
#   'losses': 9,
#   'goals_scored': 29,
#   'goals_conceded': 35},
#  7291: {'team_name': 'Odisha',
#   'matches': 20,
#   'wins': 6,
#   'draws': 5,
#   'losses': 9,
#   'goals_scored': 31,
#   'goals_conceded': 43},
#  7287: {'team_name': 'Mumbai City',
#   'matches': 20,
#   'wins': 9,
#   'draws': 4,
#   'losses': 7,
#   'goals_scored': 36,
#   'goals_conceded': 31},
#  7290: {'team_name': 'Chennaiyin',
#   'matches': 20,
#   'wins': 5,
#   'draws': 5,
#   'losses': 10,
#   'goals_scored': 17,
#   'goals_conceded': 35},
#  7285: {'team_name': 'NorthEast United',
#   'matches': 20,
#   'wins': 3,
#   'draws': 5,
#   'losses': 12,
#   'goals_scored': 25,
#   'goals_conceded': 43},
#  422: {'team_name': 'Osasuna',
#   'matches': 20,
#   'wins': 2,
#   'draws': 2,
#   'losses': 16,
#   'goals_scored': 11,
#   'goals_conceded': 62},
#  865: {'team_name': "England Women's",
#   'matches': 20,
#   'wins': 16,
#   'draws': 1,
#   'losses': 3,
#   'goals_scored': 48,
#   'goals_conceded': 11},
#  858: {'team_name': "Sweden Women's",
#   'matches': 19,
#   'wins': 13,
#   'draws': 2,
#   'losses': 4,
#   'goals_scored': 35,
#   'goals_conceded': 16},
#  771: {'team_name': 'France',
#   'matches': 19,
#   'wins': 12,
#   'draws': 5,
#   'losses': 2,
#   'goals_scored': 39,
#   'goals_conceded': 25},
#  970: {'team_name': 'Yeovil Town LFC',
#   'matches': 19,
#   'wins': 2,
#   'draws': 1,
#   'losses': 16,
#   'goals_scored': 11,
#   'goals_conceded': 52},
#  785: {'team_name': 'Croatia',
#   'matches': 18,
#   'wins': 7,
#   'draws': 7,
#   'losses': 4,
#   'goals_scored': 29,
#   'goals_conceded': 24},
#  851: {'team_name': "Netherlands Women's",
#   'matches': 16,
#   'wins': 11,
#   'draws': 2,
#   'losses': 3,
#   'goals_scored': 31,
#   'goals_conceded': 13},
#  779: {'team_name': 'Argentina',
#   'matches': 16,
#   'wins': 9,
#   'draws': 3,
#   'losses': 4,
#   'goals_scored': 29,
#   'goals_conceded': 24},
#  782: {'team_name': 'Belgium',
#   'matches': 16,
#   'wins': 11,
#   'draws': 1,
#   'losses': 4,
#   'goals_scored': 26,
#   'goals_conceded': 13},
#  863: {'team_name': "Spain Women's",
#   'matches': 15,
#   'wins': 9,
#   'draws': 1,
#   'losses': 5,
#   'goals_scored': 28,
#   'goals_conceded': 16},
#  861: {'team_name': "France Women's",
#   'matches': 15,
#   'wins': 10,
#   'draws': 3,
#   'losses': 2,
#   'goals_scored': 32,
#   'goals_conceded': 13},
#  857: {'team_name': "Germany Women's",
#   'matches': 14,
#   'wins': 10,
#   'draws': 1,
#   'losses': 3,
#   'goals_scored': 32,
#   'goals_conceded': 8},
#  941: {'team_name': 'Netherlands',
#   'matches': 14,
#   'wins': 9,
#   'draws': 3,
#   'losses': 2,
#   'goals_scored': 27,
#   'goals_conceded': 10},
#  772: {'team_name': 'Spain',
#   'matches': 14,
#   'wins': 4,
#   'draws': 9,
#   'losses': 1,
#   'goals_scored': 29,
#   'goals_conceded': 15},
#  1217: {'team_name': 'Racing Santander',
#   'matches': 13,
#   'wins': 0,
#   'draws': 2,
#   'losses': 11,
#   'goals_scored': 4,
#   'goals_conceded': 32},
#  901: {'team_name': 'Real Valladolid',
#   'matches': 13,
#   'wins': 1,
#   'draws': 1,
#   'losses': 11,
#   'goals_scored': 4,
#   'goals_conceded': 30},
#  395: {'team_name': 'Real Zaragoza',
#   'matches': 13,
#   'wins': 1,
#   'draws': 1,
#   'losses': 11,
#   'goals_scored': 11,
#   'goals_conceded': 37},
#  770: {'team_name': 'Germany',
#   'matches': 13,
#   'wins': 4,
#   'draws': 2,
#   'losses': 7,
#   'goals_scored': 18,
#   'goals_conceded': 21},
#  773: {'team_name': 'Switzerland',
#   'matches': 13,
#   'wins': 4,
#   'draws': 5,
#   'losses': 4,
#   'goals_scored': 18,
#   'goals_conceded': 23},
#  776: {'team_name': 'Denmark',
#   'matches': 13,
#   'wins': 4,
#   'draws': 4,
#   'losses': 5,
#   'goals_scored': 16,
#   'goals_conceded': 12},
#  780: {'team_name': 'Portugal',
#   'matches': 13,
#   'wins': 5,
#   'draws': 3,
#   'losses': 5,
#   'goals_scored': 25,
#   'goals_conceded': 19},
#  766: {'team_name': 'North Carolina Courage',
#   'matches': 13,
#   'wins': 9,
#   'draws': 4,
#   'losses': 0,
#   'goals_scored': 31,
#   'goals_conceded': 11},
#  1043: {'team_name': 'Mallorca',
#   'matches': 12,
#   'wins': 1,
#   'draws': 1,
#   'losses': 10,
#   'goals_scored': 10,
#   'goals_conceded': 35},
#  852: {'team_name': "Norway Women's",
#   'matches': 12,
#   'wins': 4,
#   'draws': 2,
#   'losses': 6,
#   'goals_scored': 18,
#   'goals_conceded': 21},
#  403: {'team_name': 'Almería',
#   'matches': 11,
#   'wins': 0,
#   'draws': 1,
#   'losses': 10,
#   'goals_scored': 5,
#   'goals_conceded': 35},
#  206: {'team_name': 'Deportivo Alavés',
#   'matches': 11,
#   'wins': 1,
#   'draws': 1,
#   'losses': 9,
#   'goals_scored': 6,
#   'goals_conceded': 33},
#  1214: {'team_name': "United States Women's",
#   'matches': 11,
#   'wins': 8,
#   'draws': 3,
#   'losses': 0,
#   'goals_scored': 30,
#   'goals_conceded': 4},
#  1205: {'team_name': "Australia Women's",
#   'matches': 11,
#   'wins': 5,
#   'draws': 2,
#   'losses': 4,
#   'goals_scored': 19,
#   'goals_conceded': 14},
#  855: {'team_name': "Italy Women's",
#   'matches': 11,
#   'wins': 4,
#   'draws': 1,
#   'losses': 6,
#   'goals_scored': 14,
#   'goals_conceded': 19},
#  790: {'team_name': 'Sweden',
#   'matches': 11,
#   'wins': 5,
#   'draws': 2,
#   'losses': 4,
#   'goals_scored': 13,
#   'goals_conceded': 13},
#  788: {'team_name': 'Morocco',
#   'matches': 10,
#   'wins': 3,
#   'draws': 3,
#   'losses': 4,
#   'goals_scored': 8,
#   'goals_conceded': 9},
#  789: {'team_name': 'Poland',
#   'matches': 10,
#   'wins': 2,
#   'draws': 2,
#   'losses': 6,
#   'goals_scored': 9,
#   'goals_conceded': 16},
#  1210: {'team_name': "Japan Women's",
#   'matches': 9,
#   'wins': 5,
#   'draws': 1,
#   'losses': 3,
#   'goals_scored': 18,
#   'goals_conceded': 8},
#  783: {'team_name': 'Uruguay',
#   'matches': 9,
#   'wins': 5,
#   'draws': 1,
#   'losses': 3,
#   'goals_scored': 10,
#   'goals_conceded': 8},
#  759: {'team_name': 'Washington Spirit',
#   'matches': 9,
#   'wins': 0,
#   'draws': 0,
#   'losses': 9,
#   'goals_scored': 3,
#   'goals_conceded': 18},
#  767: {'team_name': 'Utah Royals',
#   'matches': 9,
#   'wins': 5,
#   'draws': 1,
#   'losses': 3,
#   'goals_scored': 11,
#   'goals_conceded': 10},
#  205: {'team_name': 'Leganés',
#   'matches': 8,
#   'wins': 1,
#   'draws': 0,
#   'losses': 7,
#   'goals_scored': 7,
#   'goals_conceded': 21},
#  1213: {'team_name': "Nigeria Women's",
#   'matches': 8,
#   'wins': 2,
#   'draws': 3,
#   'losses': 3,
#   'goals_scored': 5,
#   'goals_conceded': 9},
#  794: {'team_name': 'Mexico',
#   'matches': 8,
#   'wins': 3,
#   'draws': 1,
#   'losses': 4,
#   'goals_scored': 5,
#   'goals_conceded': 11},
#  778: {'team_name': 'Japan',
#   'matches': 8,
#   'wins': 3,
#   'draws': 2,
#   'losses': 3,
#   'goals_scored': 11,
#   'goals_conceded': 11},
#  796: {'team_name': 'Russia',
#   'matches': 8,
#   'wins': 3,
#   'draws': 2,
#   'losses': 3,
#   'goals_scored': 13,
#   'goals_conceded': 14},
#  914: {'team_name': 'Italy',
#   'matches': 8,
#   'wins': 5,
#   'draws': 2,
#   'losses': 1,
#   'goals_scored': 14,
#   'goals_conceded': 8},
#  764: {'team_name': 'Orlando Pride',
#   'matches': 8,
#   'wins': 2,
#   'draws': 2,
#   'losses': 4,
#   'goals_scored': 10,
#   'goals_conceded': 16},
#  1212: {'team_name': "Jamaica Women's",
#   'matches': 7,
#   'wins': 1,
#   'draws': 2,
#   'losses': 4,
#   'goals_scored': 2,
#   'goals_conceded': 13},
#  1216: {'team_name': "South Africa Women's",
#   'matches': 7,
#   'wins': 1,
#   'draws': 1,
#   'losses': 5,
#   'goals_scored': 7,
#   'goals_conceded': 16},
#  1207: {'team_name': "China PR Women's",
#   'matches': 7,
#   'wins': 2,
#   'draws': 1,
#   'losses': 4,
#   'goals_scored': 3,
#   'goals_conceded': 10},
#  1206: {'team_name': "Canada Women's",
#   'matches': 7,
#   'wins': 3,
#   'draws': 1,
#   'losses': 3,
#   'goals_scored': 6,
#   'goals_conceded': 8},
#  1203: {'team_name': "Brazil Women's",
#   'matches': 7,
#   'wins': 3,
#   'draws': 1,
#   'losses': 3,
#   'goals_scored': 12,
#   'goals_conceded': 7},
#  853: {'team_name': "Denmark Women's",
#   'matches': 7,
#   'wins': 3,
#   'draws': 0,
#   'losses': 4,
#   'goals_scored': 4,
#   'goals_conceded': 8},
#  860: {'team_name': "Switzerland Women's",
#   'matches': 7,
#   'wins': 1,
#   'draws': 3,
#   'losses': 3,
#   'goals_scored': 7,
#   'goals_conceded': 13},
#  792: {'team_name': 'Australia',
#   'matches': 7,
#   'wins': 2,
#   'draws': 1,
#   'losses': 4,
#   'goals_scored': 6,
#   'goals_conceded': 11},
#  787: {'team_name': 'Senegal',
#   'matches': 7,
#   'wins': 3,
#   'draws': 1,
#   'losses': 3,
#   'goals_scored': 9,
#   'goals_conceded': 11},
#  791: {'team_name': 'South Korea',
#   'matches': 7,
#   'wins': 2,
#   'draws': 1,
#   'losses': 4,
#   'goals_scored': 8,
#   'goals_conceded': 11},
#  907: {'team_name': 'Wales',
#   'matches': 7,
#   'wins': 1,
#   'draws': 2,
#   'losses': 4,
#   'goals_scored': 4,
#   'goals_conceded': 12},
#  763: {'team_name': 'NJ/NY Gotham FC',
#   'matches': 7,
#   'wins': 0,
#   'draws': 1,
#   'losses': 6,
#   'goals_scored': 7,
#   'goals_conceded': 18},
#  761: {'team_name': 'Chicago Red Stars',
#   'matches': 7,
#   'wins': 4,
#   'draws': 2,
#   'losses': 1,
#   'goals_scored': 11,
#   'goals_conceded': 7},
#  765: {'team_name': 'Portland Thorns',
#   'matches': 7,
#   'wins': 4,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 14,
#   'goals_conceded': 10},
#  760: {'team_name': 'OL Reign',
#   'matches': 7,
#   'wins': 5,
#   'draws': 1,
#   'losses': 1,
#   'goals_scored': 10,
#   'goals_conceded': 4},
#  1204: {'team_name': "Argentina Women's",
#   'matches': 6,
#   'wins': 0,
#   'draws': 3,
#   'losses': 3,
#   'goals_scored': 5,
#   'goals_conceded': 9},
#  1211: {'team_name': "Korea Republic Women's",
#   'matches': 6,
#   'wins': 0,
#   'draws': 1,
#   'losses': 5,
#   'goals_scored': 2,
#   'goals_conceded': 12},
#  1215: {'team_name': "New Zealand Women's",
#   'matches': 6,
#   'wins': 1,
#   'draws': 1,
#   'losses': 4,
#   'goals_scored': 2,
#   'goals_conceded': 6},
#  864: {'team_name': "Portugal Women's",
#   'matches': 6,
#   'wins': 1,
#   'draws': 2,
#   'losses': 3,
#   'goals_scored': 6,
#   'goals_conceded': 11},
#  1975: {'team_name': 'Inter Miami',
#   'matches': 6,
#   'wins': 3,
#   'draws': 1,
#   'losses': 2,
#   'goals_scored': 9,
#   'goals_conceded': 3},
#  786: {'team_name': 'Serbia',
#   'matches': 6,
#   'wins': 1,
#   'draws': 1,
#   'losses': 4,
#   'goals_scored': 7,
#   'goals_conceded': 12},
#  777: {'team_name': 'Tunisia',
#   'matches': 6,
#   'wins': 2,
#   'draws': 1,
#   'losses': 3,
#   'goals_scored': 6,
#   'goals_conceded': 9},
#  799: {'team_name': 'Saudi Arabia',
#   'matches': 6,
#   'wins': 2,
#   'draws': 0,
#   'losses': 4,
#   'goals_scored': 5,
#   'goals_conceded': 12},
#  795: {'team_name': 'Costa Rica',
#   'matches': 6,
#   'wins': 1,
#   'draws': 1,
#   'losses': 4,
#   'goals_scored': 5,
#   'goals_conceded': 16},
#  797: {'team_name': 'Iran',
#   'matches': 6,
#   'wins': 2,
#   'draws': 1,
#   'losses': 3,
#   'goals_scored': 6,
#   'goals_conceded': 9},
#  1220: {'team_name': 'Recreativo Huelva',
#   'matches': 5,
#   'wins': 0,
#   'draws': 1,
#   'losses': 4,
#   'goals_scored': 2,
#   'goals_conceded': 13},
#  16802: {'team_name': "Colombia Women's",
#   'matches': 5,
#   'wins': 3,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 6,
#   'goals_conceded': 4},
#  912: {'team_name': 'Czech Republic',
#   'matches': 5,
#   'wins': 2,
#   'draws': 1,
#   'losses': 2,
#   'goals_scored': 6,
#   'goals_conceded': 4},
#  911: {'team_name': 'Ukraine',
#   'matches': 5,
#   'wins': 2,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 6,
#   'goals_conceded': 10},
#  762: {'team_name': 'Houston Dash',
#   'matches': 5,
#   'wins': 1,
#   'draws': 1,
#   'losses': 3,
#   'goals_scored': 7,
#   'goals_conceded': 10},
#  1042: {'team_name': 'Elche',
#   'matches': 4,
#   'wins': 0,
#   'draws': 1,
#   'losses': 3,
#   'goals_scored': 0,
#   'goals_conceded': 12},
#  211: {'team_name': 'Girona',
#   'matches': 4,
#   'wins': 0,
#   'draws': 1,
#   'losses': 3,
#   'goals_scored': 3,
#   'goals_conceded': 13},
#  143: {'team_name': 'Lille',
#   'matches': 4,
#   'wins': 0,
#   'draws': 0,
#   'losses': 4,
#   'goals_scored': 6,
#   'goals_conceded': 18},
#  134: {'team_name': 'Rennes',
#   'matches': 4,
#   'wins': 3,
#   'draws': 0,
#   'losses': 1,
#   'goals_scored': 5,
#   'goals_conceded': 1},
#  147: {'team_name': 'Marseille',
#   'matches': 4,
#   'wins': 0,
#   'draws': 1,
#   'losses': 3,
#   'goals_scored': 1,
#   'goals_conceded': 6},
#  144: {'team_name': 'Nantes',
#   'matches': 4,
#   'wins': 1,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 6,
#   'goals_conceded': 11},
#  136: {'team_name': 'OGC Nice',
#   'matches': 4,
#   'wins': 1,
#   'draws': 1,
#   'losses': 2,
#   'goals_scored': 2,
#   'goals_conceded': 4},
#  1208: {'team_name': "Cameroon Women's",
#   'matches': 4,
#   'wins': 1,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 3,
#   'goals_conceded': 8},
#  2391: {'team_name': "Morocco Women's",
#   'matches': 4,
#   'wins': 2,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 2,
#   'goals_conceded': 10},
#  1839: {'team_name': 'United States',
#   'matches': 4,
#   'wins': 1,
#   'draws': 2,
#   'losses': 1,
#   'goals_scored': 3,
#   'goals_conceded': 4},
#  769: {'team_name': 'Colombia',
#   'matches': 4,
#   'wins': 2,
#   'draws': 1,
#   'losses': 1,
#   'goals_scored': 6,
#   'goals_conceded': 3},
#  784: {'team_name': 'Peru',
#   'matches': 4,
#   'wins': 1,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 4,
#   'goals_conceded': 6},
#  859: {'team_name': "Austria Women's",
#   'matches': 4,
#   'wins': 2,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 3,
#   'goals_conceded': 3},
#  854: {'team_name': "Belgium Women's",
#   'matches': 4,
#   'wins': 1,
#   'draws': 1,
#   'losses': 2,
#   'goals_scored': 3,
#   'goals_conceded': 4},
#  915: {'team_name': 'Austria',
#   'matches': 4,
#   'wins': 2,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 5,
#   'goals_conceded': 5},
#  902: {'team_name': 'Huesca',
#   'matches': 3,
#   'wins': 0,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 3,
#   'goals_conceded': 13},
#  552: {'team_name': 'Cádiz',
#   'matches': 3,
#   'wins': 1,
#   'draws': 1,
#   'losses': 1,
#   'goals_scored': 4,
#   'goals_conceded': 5},
#  152: {'team_name': 'Clermont Foot',
#   'matches': 3,
#   'wins': 1,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 4,
#   'goals_conceded': 13},
#  156: {'team_name': 'Stade de Reims',
#   'matches': 3,
#   'wins': 0,
#   'draws': 1,
#   'losses': 2,
#   'goals_scored': 1,
#   'goals_conceded': 7},
#  168: {'team_name': 'Lens',
#   'matches': 3,
#   'wins': 0,
#   'draws': 2,
#   'losses': 1,
#   'goals_scored': 3,
#   'goals_conceded': 5},
#  139: {'team_name': 'Montpellier',
#   'matches': 3,
#   'wins': 0,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 3,
#   'goals_conceded': 12},
#  137: {'team_name': 'Lyon',
#   'matches': 3,
#   'wins': 1,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 2,
#   'goals_conceded': 3},
#  165: {'team_name': 'Lorient',
#   'matches': 3,
#   'wins': 1,
#   'draws': 1,
#   'losses': 1,
#   'goals_scored': 5,
#   'goals_conceded': 7},
#  129: {'team_name': 'AS Monaco',
#   'matches': 3,
#   'wins': 0,
#   'draws': 1,
#   'losses': 2,
#   'goals_scored': 1,
#   'goals_conceded': 6},
#  806: {'team_name': 'Ajax',
#   'matches': 3,
#   'wins': 3,
#   'draws': 0,
#   'losses': 0,
#   'goals_scored': 5,
#   'goals_conceded': 0},
#  1107: {'team_name': "Thailand Women's",
#   'matches': 3,
#   'wins': 0,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 1,
#   'goals_conceded': 20},
#  1209: {'team_name': "Chile Women's",
#   'matches': 3,
#   'wins': 1,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 2,
#   'goals_conceded': 5},
#  866: {'team_name': "Scotland Women's",
#   'matches': 3,
#   'wins': 0,
#   'draws': 1,
#   'losses': 2,
#   'goals_scored': 5,
#   'goals_conceded': 7},
#  6045: {'team_name': "Zambia Women's",
#   'matches': 3,
#   'wins': 1,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 3,
#   'goals_conceded': 11},
#  16803: {'team_name': "Panama Women's",
#   'matches': 3,
#   'wins': 0,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 3,
#   'goals_conceded': 11},
#  1832: {'team_name': "Costa Rica Women's",
#   'matches': 3,
#   'wins': 0,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 1,
#   'goals_conceded': 8},
#  2355: {'team_name': "Haiti Women's",
#   'matches': 3,
#   'wins': 0,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 0,
#   'goals_conceded': 4},
#  16769: {'team_name': "Vietnam Women's",
#   'matches': 3,
#   'wins': 0,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 0,
#   'goals_conceded': 12},
#  16768: {'team_name': "Republic of Ireland Women's",
#   'matches': 3,
#   'wins': 0,
#   'draws': 1,
#   'losses': 2,
#   'goals_scored': 1,
#   'goals_conceded': 3},
#  1106: {'team_name': "Philippines Women's",
#   'matches': 3,
#   'wins': 1,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 1,
#   'goals_conceded': 8},
#  3565: {'team_name': 'Ecuador',
#   'matches': 3,
#   'wins': 1,
#   'draws': 1,
#   'losses': 1,
#   'goals_scored': 4,
#   'goals_conceded': 3},
#  3566: {'team_name': 'Qatar',
#   'matches': 3,
#   'wins': 0,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 1,
#   'goals_conceded': 7},
#  2722: {'team_name': 'Cameroon',
#   'matches': 3,
#   'wins': 1,
#   'draws': 1,
#   'losses': 1,
#   'goals_scored': 4,
#   'goals_conceded': 4},
#  4885: {'team_name': 'Ghana',
#   'matches': 3,
#   'wins': 1,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 5,
#   'goals_conceded': 7},
#  1833: {'team_name': 'Canada',
#   'matches': 3,
#   'wins': 0,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 2,
#   'goals_conceded': 7},
#  798: {'team_name': 'Panama',
#   'matches': 3,
#   'wins': 0,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 2,
#   'goals_conceded': 11},
#  774: {'team_name': 'Egypt',
#   'matches': 3,
#   'wins': 0,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 2,
#   'goals_conceded': 6},
#  775: {'team_name': 'Nigeria',
#   'matches': 3,
#   'wins': 1,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 3,
#   'goals_conceded': 4},
#  793: {'team_name': 'Iceland',
#   'matches': 3,
#   'wins': 0,
#   'draws': 1,
#   'losses': 2,
#   'goals_scored': 2,
#   'goals_conceded': 5},
#  2457: {'team_name': 'Northern Ireland',
#   'matches': 3,
#   'wins': 0,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 1,
#   'goals_conceded': 11},
#  862: {'team_name': "Iceland Women's",
#   'matches': 3,
#   'wins': 0,
#   'draws': 3,
#   'losses': 0,
#   'goals_scored': 3,
#   'goals_conceded': 3},
#  920: {'team_name': 'WNT Finland',
#   'matches': 3,
#   'wins': 0,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 1,
#   'goals_conceded': 8},
#  908: {'team_name': 'Slovakia',
#   'matches': 3,
#   'wins': 1,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 2,
#   'goals_conceded': 7},
#  909: {'team_name': 'Turkey',
#   'matches': 3,
#   'wins': 0,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 1,
#   'goals_conceded': 8},
#  2358: {'team_name': 'North Macedonia',
#   'matches': 3,
#   'wins': 0,
#   'draws': 0,
#   'losses': 3,
#   'goals_scored': 2,
#   'goals_conceded': 8},
#  916: {'team_name': 'Hungary',
#   'matches': 3,
#   'wins': 0,
#   'draws': 2,
#   'losses': 1,
#   'goals_scored': 3,
#   'goals_conceded': 6},
#  942: {'team_name': 'Scotland',
#   'matches': 3,
#   'wins': 0,
#   'draws': 1,
#   'losses': 2,
#   'goals_scored': 1,
#   'goals_conceded': 5},
#  1835: {'team_name': 'Finland',
#   'matches': 3,
#   'wins': 1,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 1,
#   'goals_conceded': 3},
#  444: {'team_name': 'CD Numancia de Soria',
#   'matches': 2,
#   'wins': 1,
#   'draws': 0,
#   'losses': 1,
#   'goals_scored': 2,
#   'goals_conceded': 4},
#  608: {'team_name': 'Albacete',
#   'matches': 2,
#   'wins': 0,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 1,
#   'goals_conceded': 4},
#  627: {'team_name': 'Tenerife',
#   'matches': 2,
#   'wins': 0,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 1,
#   'goals_conceded': 9},
#  1219: {'team_name': 'Xerez',
#   'matches': 2,
#   'wins': 0,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 1,
#   'goals_conceded': 5},
#  373: {'team_name': 'Córdoba CF',
#   'matches': 2,
#   'wins': 0,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 0,
#   'goals_conceded': 13},
#  1218: {'team_name': 'Hércules',
#   'matches': 2,
#   'wins': 1,
#   'draws': 0,
#   'losses': 1,
#   'goals_scored': 2,
#   'goals_conceded': 3},
#  138: {'team_name': 'Strasbourg',
#   'matches': 2,
#   'wins': 0,
#   'draws': 2,
#   'losses': 0,
#   'goals_scored': 4,
#   'goals_conceded': 4},
#  135: {'team_name': 'Saint-Étienne',
#   'matches': 2,
#   'wins': 0,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 2,
#   'goals_conceded': 6},
#  133: {'team_name': 'Troyes',
#   'matches': 2,
#   'wins': 0,
#   'draws': 1,
#   'losses': 1,
#   'goals_scored': 5,
#   'goals_conceded': 6},
#  158: {'team_name': 'AC Ajaccio',
#   'matches': 2,
#   'wins': 0,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 0,
#   'goals_conceded': 8},
#  153: {'team_name': 'Stade Brestois',
#   'matches': 2,
#   'wins': 0,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 1,
#   'goals_conceded': 3},
#  145: {'team_name': 'Angers',
#   'matches': 2,
#   'wins': 0,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 1,
#   'goals_conceded': 4},
#  167: {'team_name': 'Auxerre',
#   'matches': 2,
#   'wins': 0,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 1,
#   'goals_conceded': 7},
#  130: {'team_name': 'Toulouse',
#   'matches': 2,
#   'wins': 0,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 1,
#   'goals_conceded': 5},
#  1328: {'team_name': 'Boca Juniors',
#   'matches': 2,
#   'wins': 2,
#   'draws': 0,
#   'losses': 0,
#   'goals_scored': 5,
#   'goals_conceded': 1},
#  1324: {'team_name': 'River Plate',
#   'matches': 2,
#   'wins': 0,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 1,
#   'goals_conceded': 5},
#  2721: {'team_name': 'German DR',
#   'matches': 2,
#   'wins': 1,
#   'draws': 0,
#   'losses': 1,
#   'goals_scored': 1,
#   'goals_conceded': 2},
#  46: {'team_name': 'Wolverhampton Wanderers',
#   'matches': 2,
#   'wins': 0,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 1,
#   'goals_conceded': 6},
#  75: {'team_name': 'Charlton Athletic',
#   'matches': 2,
#   'wins': 0,
#   'draws': 1,
#   'losses': 1,
#   'goals_scored': 2,
#   'goals_conceded': 3},
#  47: {'team_name': 'Middlesbrough',
#   'matches': 2,
#   'wins': 0,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 1,
#   'goals_conceded': 8},
#  101: {'team_name': 'Leeds United',
#   'matches': 2,
#   'wins': 0,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 1,
#   'goals_conceded': 9},
#  98: {'team_name': 'Blackburn Rovers',
#   'matches': 2,
#   'wins': 0,
#   'draws': 0,
#   'losses': 2,
#   'goals_scored': 0,
#   'goals_conceded': 3},
#  54: {'team_name': 'Birmingham City',
#   'matches': 2,
#   'wins': 0,
#   'draws': 1,
#   'losses': 1,
#   'goals_scored': 0,
#   'goals_conceded': 3},
#  105: {'team_name': 'Portsmouth',
#   'matches': 2,
#   'wins': 0,
#   'draws': 2,
#   'losses': 0,
#   'goals_scored': 2,
#   'goals_conceded': 2},
#  55: {'team_name': 'Fulham',
#   'matches': 2,
#   'wins': 0,
#   'draws': 1,
#   'losses': 1,
#   'goals_scored': 0,
#   'goals_conceded': 1},
#  328: {'team_name': 'Bolton Wanderers',
#   'matches': 2,
#   'wins': 0,
#   'draws': 1,
#   'losses': 1,
#   'goals_scored': 2,
#   'goals_conceded': 3},
#  1076: {'team_name': 'Juventus',
#   'matches': 1,
#   'wins': 0,
#   'draws': 0,
#   'losses': 1,
#   'goals_scored': 0,
#   'goals_conceded': 3},
#  1230: {'team_name': 'Real Murcia CF',
#   'matches': 1,
#   'wins': 0,
#   'draws': 0,
#   'losses': 1,
#   'goals_scored': 3,
#   'goals_conceded': 5},
#  1036: {'team_name': 'Gimnàstic Tarragona',
#   'matches': 1,
#   'wins': 0,
#   'draws': 0,
#   'losses': 1,
#   'goals_scored': 1,
#   'goals_conceded': 5},
#  146: {'team_name': 'Bordeaux',
#   'matches': 1,
#   'wins': 0,
#   'draws': 0,
#   'losses': 1,
#   'goals_scored': 0,
#   'goals_conceded': 3},
#  141: {'team_name': 'Metz',
#   'matches': 1,
#   'wins': 0,
#   'draws': 0,
#   'losses': 1,
#   'goals_scored': 0,
#   'goals_conceded': 5},
#  952: {'team_name': 'Panathinaikos',
#   'matches': 1,
#   'wins': 0,
#   'draws': 0,
#   'losses': 1,
#   'goals_scored': 0,
#   'goals_conceded': 2},
#  256: {'team_name': 'FC Porto',
#   'matches': 1,
#   'wins': 1,
#   'draws': 0,
#   'losses': 0,
#   'goals_scored': 3,
#   'goals_conceded': 0},
#  2735: {'team_name': 'NY Cosmos',
#   'matches': 1,
#   'wins': 1,
#   'draws': 0,
#   'losses': 0,
#   'goals_scored': 2,
#   'goals_conceded': 1},
#  488: {'team_name': 'Seattle Sounders',
#   'matches': 1,
#   'wins': 0,
#   'draws': 0,
#   'losses': 1,
#   'goals_scored': 1,
#   'goals_conceded': 2},
#  387: {'team_name': 'New York Red Bulls',
#   'matches': 1,
#   'wins': 0,
#   'draws': 0,
#   'losses': 1,
#   'goals_scored': 0,
#   'goals_conceded': 2},
#  919: {'team_name': 'LAFC',
#   'matches': 1,
#   'wins': 0,
#   'draws': 0,
#   'losses': 1,
#   'goals_scored': 1,
#   'goals_conceded': 3},
#  8070: {'team_name': 'Charlotte',
#   'matches': 1,
#   'wins': 1,
#   'draws': 0,
#   'losses': 0,
#   'goals_scored': 1,
#   'goals_conceded': 0},
#  1938: {'team_name': 'Nashville SC',
#   'matches': 1,
#   'wins': 0,
#   'draws': 1,
#   'losses': 0,
#   'goals_scored': 0,
#   'goals_conceded': 0},
#  489: {'team_name': 'Cincinnati',
#   'matches': 1,
#   'wins': 1,
#   'draws': 0,
#   'losses': 0,
#   'goals_scored': 1,
#   'goals_conceded': 0},
#  575: {'team_name': 'Toronto FC',
#   'matches': 1,
#   'wins': 0,
#   'draws': 0,
#   'losses': 1,
#   'goals_scored': 0,
#   'goals_conceded': 4},
#  905: {'team_name': 'Romania',
#   'matches': 1,
#   'wins': 0,
#   'draws': 0,
#   'losses': 1,
#   'goals_scored': 2,
#   'goals_conceded': 3},
#  17469: {'team_name': 'Czechoslovakia',
#   'matches': 1,
#   'wins': 0,
#   'draws': 0,
#   'losses': 1,
#   'goals_scored': 1,
#   'goals_conceded': 4},
#  9763: {'team_name': 'Argentina U20',
#   'matches': 1,
#   'wins': 1,
#   'draws': 0,
#   'losses': 0,
#   'goals_scored': 3,
#   'goals_conceded': 1},
#  17403: {'team_name': 'Soviet Union U20',
#   'matches': 1,
#   'wins': 0,
#   'draws': 0,
#   'losses': 1,
#   'goals_scored': 1,
#   'goals_conceded': 3}}
